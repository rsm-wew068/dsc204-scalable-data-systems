# %% [markdown]
# # Task 1: Feature Engineering with Modin on Ray
# In this task, we'll perform some feature engineering for the Amazon Reviews dataset. We'll use Modin so that you can conveniently write pandas code and have your workload scale to a cluster.

# %%
import ray
ray.shutdown()
ray.init()
import os 
import json
import modin.pandas as pd
import numpy as np
from ast import literal_eval
from pathlib import Path

def compare_dicts(d1, d2, err=1e-5):
    keys1 = set(d1.keys())
    keys2 = set(d2.keys())
    if keys1 != keys2:
        return False
    for k in keys1:
        if isinstance(d1[k], list) and isinstance(d2[k], list):
            if sum([abs(x - y) for x, y in zip(d1[k], d2[k])]) > err:
                return False
        else:
            v1 = float(d1[k])
            v2 = float(d2[k])
            if abs(v1 - v2) > err:
                return False
    return True
# Out:
# 2025-11-16 14:51:43,030	INFO worker.py:2004 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# /opt/homebrew/Caskroom/miniconda/base/envs/ray_env/lib/python3.10/site-packages/ray/_private/worker.py:2052: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# (_remote_exec_multi_chain pid=10551) . fn=<function Map.register.<locals>.caller.<locals>.<lambda> at 0x11d5a39a0>, obj=       categories
# (_remote_exec_multi_chain pid=10551) 56630   [[Books]]
# (_remote_exec_multi_chain pid=10551) 56631   [[Books]]
# (_remote_exec_multi_chain pid=10551) 56632   [[Books]]
# (_remote_exec_multi_chain pid=10551) 56633   [[Books]]
# (_remote_exec_multi_chain pid=10551) 56634   [[Books]]
# (_remote_exec_multi_chain pid=10551) ...           ...
# (_remote_exec_multi_chain pid=10551) 139235  [[Books]]
# (_remote_exec_multi_chain pid=10551) 139236  [[Books]]
# (_remote_exec_multi_chain pid=10551) 139237  [[Books]]
# (_remote_exec_multi_chain pid=10551) 139238  [[Books]]
# (_remote_exec_multi_chain pid=10551) 139239  [[Books]]
# (_remote_exec_multi_chain pid=10551)
# (_remote_exec_multi_chain pid=10551) [82610 rows x 1 columns], args=[], kwargs={}
# (_remote_exec_multi_chain pid=10551) . args=(       categories
# (_remote_exec_multi_chain pid=10551) 56630   [[Books]]
# (_remote_exec_multi_chain pid=10551) 56631   [[Books]]
# (_remote_exec_multi_chain pid=10551) 56632   [[Books]]
# (_remote_exec_multi_chain pid=10551) 56633   [[Books]]
# (_remote_exec_multi_chain pid=10551) 56634   [[Books]]
# (_remote_exec_multi_chain pid=10551) ...           ...
# (_remote_exec_multi_chain pid=10551) 139235  [[Books]]
# (_remote_exec_multi_chain pid=10551) 139236  [[Books]]
# (_remote_exec_multi_chain pid=10551) 139237  [[Books]]
# (_remote_exec_multi_chain pid=10551) 139238  [[Books]]
# (_remote_exec_multi_chain pid=10551) 139239  [[Books]]
# (_remote_exec_multi_chain pid=10551)
# (_remote_exec_multi_chain pid=10551) [82610 rows x 1 columns], <function PandasDataframePartition._iloc at 0x11ff47520>, 2, slice(None, None, None), array([0]), 0, 0, 1, <function Map.register.<locals>.caller.<locals>.<lambda> at 0x11d5a39a0>, 0, 0, 0, 1), chain=[0, 1]
# (_remote_exec_multi_chain pid=10558)
# (_remote_exec_multi_chain pid=10558)
# (_remote_exec_multi_chain pid=10553) 541930  [[Electronics, Television & Video, Blu-ray Pla...
# (_remote_exec_multi_chain pid=10553) 541931  [[Electronics, Computers & Accessories, Laptops]]
# (_remote_exec_multi_chain pid=10553) 541932  [[Electronics, Computers & Accessories, Laptops]]
# (_remote_exec_multi_chain pid=10553) 541933  [[Electronics, Computers & Accessories, Touch ...
# (_remote_exec_multi_chain pid=10553) 541934  [[Electronics, Television & Video, Analog-to-D...
# (_remote_exec_multi_chain pid=10553) 606784                                [[Movies & TV, TV]]
# (_remote_exec_multi_chain pid=10553) 606785                            [[Movies & TV, Movies]]
# (_remote_exec_multi_chain pid=10553) 606786                            [[Movies & TV, Movies]]
# (_remote_exec_multi_chain pid=10553) 606787                                [[Movies & TV, TV]]
# (_remote_exec_multi_chain pid=10553) 606788                            [[Movies & TV, Movies]]
# (_remote_exec_multi_chain pid=10553)
# (_remote_exec_multi_chain pid=10553) 541930  [[Electronics, Television & Video, Blu-ray Pla...
# (_remote_exec_multi_chain pid=10553) 541931  [[Electronics, Computers & Accessories, Laptops]]
# (_remote_exec_multi_chain pid=10553) 541932  [[Electronics, Computers & Accessories, Laptops]]
# (_remote_exec_multi_chain pid=10553) 541933  [[Electronics, Computers & Accessories, Touch ...
# (_remote_exec_multi_chain pid=10553) 541934  [[Electronics, Television & Video, Analog-to-D...
# (_remote_exec_multi_chain pid=10553) 606784                                [[Movies & TV, TV]]
# (_remote_exec_multi_chain pid=10553) 606785                            [[Movies & TV, Movies]]
# (_remote_exec_multi_chain pid=10553) 606786                            [[Movies & TV, Movies]]
# (_remote_exec_multi_chain pid=10553) 606787                                [[Movies & TV, TV]]
# (_remote_exec_multi_chain pid=10553) 606788                            [[Movies & TV, Movies]]
# (_remote_exec_multi_chain pid=10553)
# (_remote_exec_multi_chain pid=10558) 416549  [[CDs & Vinyl, Broadway & Vocalists, Tradition...
# (_remote_exec_multi_chain pid=10558) 416550  [[CDs & Vinyl, Christian, Rap & Hip-Hop], [CDs...
# (_remote_exec_multi_chain pid=10558) 416551  [[CDs & Vinyl, Christian, Pop & Contemporary],...
# (_remote_exec_multi_chain pid=10558) 416552  [[CDs & Vinyl, Metal, Alternative Metal], [CDs...
# (_remote_exec_multi_chain pid=10558) 416553  [[CDs & Vinyl, Metal], [CDs & Vinyl, Pop], [CD...
# (_remote_exec_multi_chain pid=10558) 473436  [[Clothing, Shoes & Jewelry, Shoes & Accessori...
# (_remote_exec_multi_chain pid=10558) 473437  [[Clothing, Shoes & Jewelry, C, Calvin Klein],...
# (_remote_exec_multi_chain pid=10558) 473438  [[Clothing, Shoes & Jewelry, C, Calvin Klein],...
# (_remote_exec_multi_chain pid=10558) 473439  [[Clothing, Shoes & Jewelry, New Arrivals], [C...
# (_remote_exec_multi_chain pid=10558) 473440  [[Clothing, Shoes & Jewelry, Shoes & Accessori...
# (_remote_exec_multi_chain pid=10558)
# (_remote_exec_multi_chain pid=10558) 416549  [[CDs & Vinyl, Broadway & Vocalists, Tradition...
# (_remote_exec_multi_chain pid=10558) 416550  [[CDs & Vinyl, Christian, Rap & Hip-Hop], [CDs...
# (_remote_exec_multi_chain pid=10558) 416551  [[CDs & Vinyl, Christian, Pop & Contemporary],...
# (_remote_exec_multi_chain pid=10558) 416552  [[CDs & Vinyl, Metal, Alternative Metal], [CDs...
# (_remote_exec_multi_chain pid=10558) 416553  [[CDs & Vinyl, Metal], [CDs & Vinyl, Pop], [CD...
# (_remote_exec_multi_chain pid=10558) 473436  [[Clothing, Shoes & Jewelry, Shoes & Accessori...
# (_remote_exec_multi_chain pid=10558) 473437  [[Clothing, Shoes & Jewelry, C, Calvin Klein],...
# (_remote_exec_multi_chain pid=10558) 473438  [[Clothing, Shoes & Jewelry, C, Calvin Klein],...
# (_remote_exec_multi_chain pid=10558) 473439  [[Clothing, Shoes & Jewelry, New Arrivals], [C...
# (_remote_exec_multi_chain pid=10558) 473440  [[Clothing, Shoes & Jewelry, Shoes & Accessori...
# (_remote_exec_multi_chain pid=10558)
# (_remote_exec_multi_chain pid=10553) 606789                            [[Movies & TV, Movies]]
# (_remote_exec_multi_chain pid=10553) 606790                                [[Movies & TV, TV]]
# (_remote_exec_multi_chain pid=10553) 606791                                [[Movies & TV, TV]]
# (_remote_exec_multi_chain pid=10553) 606792  [[CDs & Vinyl, Classical], [CDs & Vinyl, Opera...
# (_remote_exec_multi_chain pid=10553) 606793                                [[Movies & TV, TV]]
# (_remote_exec_multi_chain pid=10553) 657001  [[Video Games, Mac, Games], [Video Games, PC, ...
# (_remote_exec_multi_chain pid=10553) 657002  [[Video Games, Kids & Family, PlayStation 3, G...
# (_remote_exec_multi_chain pid=10553) 657003     [[Video Games, Mac, Accessories, Gaming Mice]]
# (_remote_exec_multi_chain pid=10553) 657004                [[Video Games, Xbox One, Consoles]]
# (_remote_exec_multi_chain pid=10553) 657005                   [[Video Games, Wii U, Consoles]]
# (_remote_exec_multi_chain pid=10553)
# (_remote_exec_multi_chain pid=10553) 606789                            [[Movies & TV, Movies]]
# (_remote_exec_multi_chain pid=10553) 606790                                [[Movies & TV, TV]]
# (_remote_exec_multi_chain pid=10553) 606791                                [[Movies & TV, TV]]
# (_remote_exec_multi_chain pid=10553) 606792  [[CDs & Vinyl, Classical], [CDs & Vinyl, Opera...
# (_remote_exec_multi_chain pid=10553) 606793                                [[Movies & TV, TV]]
# (_remote_exec_multi_chain pid=10553) 657001  [[Video Games, Mac, Games], [Video Games, PC, ...
# (_remote_exec_multi_chain pid=10553) 657002  [[Video Games, Kids & Family, PlayStation 3, G...
# (_remote_exec_multi_chain pid=10553) 657003     [[Video Games, Mac, Accessories, Gaming Mice]]
# (_remote_exec_multi_chain pid=10553) 657004                [[Video Games, Xbox One, Consoles]]
# (_remote_exec_multi_chain pid=10553) 657005                   [[Video Games, Wii U, Consoles]]
# (_remote_exec_multi_chain pid=10553)
# (_remote_exec_multi_chain pid=10551) 313917  [[Books, Cookbooks, Food & Wine, Desserts], [B...
# (_remote_exec_multi_chain pid=10551) 313918  [[Books, Cookbooks, Food & Wine, Desserts, Cho...
# (_remote_exec_multi_chain pid=10551) 313919  [[Books, Cookbooks, Food & Wine, Beverages & W...
# (_remote_exec_multi_chain pid=10551) 313920  [[Books, Cookbooks, Food & Wine, Main Courses ...
# (_remote_exec_multi_chain pid=10551) 313921  [[Books, Literature & Fiction], [Books, Romanc...
# (_remote_exec_multi_chain pid=10551) 361818  [[Books, Business & Money, Marketing & Sales, ...
# (_remote_exec_multi_chain pid=10551) 361819  [[Books, Literature & Fiction], [Books, Romanc...
# (_remote_exec_multi_chain pid=10551) 361820  [[Books, Literature & Fiction], [Books, Romanc...
# (_remote_exec_multi_chain pid=10551) 361821  [[Books, Literature & Fiction, Short Stories, ...
# (_remote_exec_multi_chain pid=10551) 361822  [[Books, Computers & Technology, Computer Scie...
# (_remote_exec_multi_chain pid=10551)
# (_remote_exec_multi_chain pid=10551) 313917  [[Books, Cookbooks, Food & Wine, Desserts], [B...
# (_remote_exec_multi_chain pid=10551) 313918  [[Books, Cookbooks, Food & Wine, Desserts, Cho...
# (_remote_exec_multi_chain pid=10551) 313919  [[Books, Cookbooks, Food & Wine, Beverages & W...
# (_remote_exec_multi_chain pid=10551) 313920  [[Books, Cookbooks, Food & Wine, Main Courses ...
# (_remote_exec_multi_chain pid=10551) 313921  [[Books, Literature & Fiction], [Books, Romanc...
# (_remote_exec_multi_chain pid=10551) 361818  [[Books, Business & Money, Marketing & Sales, ...
# (_remote_exec_multi_chain pid=10551) 361819  [[Books, Literature & Fiction], [Books, Romanc...
# (_remote_exec_multi_chain pid=10551) 361820  [[Books, Literature & Fiction], [Books, Romanc...
# (_remote_exec_multi_chain pid=10551) 361821  [[Books, Literature & Fiction, Short Stories, ...
# (_remote_exec_multi_chain pid=10551) 361822  [[Books, Computers & Technology, Computer Scie...
# (_remote_exec_multi_chain pid=10551)
# (_remote_exec_multi_chain pid=10553) 313912  [[Books, Mystery, Thriller & Suspense, Mystery...
# (_remote_exec_multi_chain pid=10553) 313913  [[Books, Literature & Fiction, Genre Fiction, ...
# (_remote_exec_multi_chain pid=10553) 313914  [[Books, Literature & Fiction], [Books, Myster...
# (_remote_exec_multi_chain pid=10553) 313915  [[Books, Cookbooks, Food & Wine, Cooking by In...
# (_remote_exec_multi_chain pid=10553) 313916  [[Books, Cookbooks, Food & Wine, Quick & Easy]...
# (_remote_exec_multi_chain pid=10553)
# (_remote_exec_multi_chain pid=10553) 313912  [[Books, Mystery, Thriller & Suspense, Mystery...
# (_remote_exec_multi_chain pid=10553) 313913  [[Books, Literature & Fiction, Genre Fiction, ...
# (_remote_exec_multi_chain pid=10553) 313914  [[Books, Literature & Fiction], [Books, Myster...
# (_remote_exec_multi_chain pid=10553) 313915  [[Books, Cookbooks, Food & Wine, Cooking by In...
# (_remote_exec_multi_chain pid=10553) 313916  [[Books, Cookbooks, Food & Wine, Quick & Easy]...
# (_remote_exec_multi_chain pid=10553)
# (_remote_exec_multi_chain pid=10553) 473442               [[Clothing, Shoes & Jewelry, Women]]
# (_remote_exec_multi_chain pid=10553) 473443  [[Clothing, Shoes & Jewelry, Novelty, Costumes...
# (_remote_exec_multi_chain pid=10553) 473444  [[Sports & Outdoors, Clothing, Women, Pants], ...
# (_remote_exec_multi_chain pid=10553) 473445  [[Clothing, Shoes & Jewelry, Men, Accessories,...
# (_remote_exec_multi_chain pid=10553) 541925  [[Electronics, Television & Video, Televisions...
# (_remote_exec_multi_chain pid=10553) 541926  [[Electronics, Television & Video, Televisions...
# (_remote_exec_multi_chain pid=10553) 541927  [[Electronics, Camera & Photo, Tripods & Monop...
# (_remote_exec_multi_chain pid=10553) 541928  [[Electronics, Television & Video, DVD Players...
# (_remote_exec_multi_chain pid=10553) 541929  [[Electronics, Television & Video, Blu-ray Pla...
# (_remote_exec_multi_chain pid=10553)
# (_remote_exec_multi_chain pid=10553) 473442               [[Clothing, Shoes & Jewelry, Women]]
# (_remote_exec_multi_chain pid=10553) 473443  [[Clothing, Shoes & Jewelry, Novelty, Costumes...
# (_remote_exec_multi_chain pid=10553) 473444  [[Sports & Outdoors, Clothing, Women, Pants], ...
# (_remote_exec_multi_chain pid=10553) 473445  [[Clothing, Shoes & Jewelry, Men, Accessories,...
# (_remote_exec_multi_chain pid=10553) 541925  [[Electronics, Television & Video, Televisions...
# (_remote_exec_multi_chain pid=10553) 541926  [[Electronics, Television & Video, Televisions...
# (_remote_exec_multi_chain pid=10553) 541927  [[Electronics, Camera & Photo, Tripods & Monop...
# (_remote_exec_multi_chain pid=10553) 541928  [[Electronics, Television & Video, DVD Players...
# (_remote_exec_multi_chain pid=10553) 541929  [[Electronics, Television & Video, Blu-ray Pla...
# (_remote_exec_multi_chain pid=10553)
# (_remote_exec_single_chain pid=10549) 0       [[Baby]]
# (_remote_exec_single_chain pid=10549) 1       [[Baby]]
# (_remote_exec_single_chain pid=10549) 2       [[Baby]]
# (_remote_exec_single_chain pid=10549) 3       [[Baby]]
# (_remote_exec_single_chain pid=10549) 4       [[Baby]]
# (_remote_exec_single_chain pid=10549)
# (_remote_exec_single_chain pid=10549) 0       [[Baby]]
# (_remote_exec_single_chain pid=10549) 1       [[Baby]]
# (_remote_exec_single_chain pid=10549) 2       [[Baby]]
# (_remote_exec_single_chain pid=10549) 3       [[Baby]]
# (_remote_exec_single_chain pid=10549) 4       [[Baby]]
# (_remote_exec_single_chain pid=10549)
# (_remote_exec_single_chain pid=10549) [56630 rows x 1 columns], <function Map.register.<locals>.caller.<locals>.<lambda> at 0x127b34d30>, 0, 0, 0, 1), chain=[0, 1]
# (_remote_exec_single_chain pid=10549) . fn=<function Map.register.<locals>.caller.<locals>.<lambda> at 0x127b34d30>, obj=      categories [repeated 8x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (_remote_exec_single_chain pid=10549) 56629  [[Books]] [repeated 40x across cluster]
# (_remote_exec_single_chain pid=10549) ...          ... [repeated 16x across cluster]
# (_remote_exec_single_chain pid=10549) [56630 rows x 1 columns], args=[], kwargs={} [repeated 8x across cluster]
# (_remote_exec_single_chain pid=10549) . args=(      categories [repeated 8x across cluster]
# (_remote_exec_multi_chain pid=10553) [68489 rows x 1 columns], <function PandasDataframePartition._iloc at 0x12fb41000>, 2, slice(None, None, None), array([0]), 0, 0, 1, <function Map.register.<locals>.caller.<locals>.<lambda> at 0x1293e7e20>, 0, 0, 0, 1), chain=[0, 1] [repeated 7x across cluster]
# (_remote_exec_multi_chain pid=10553) 473441  [[Clothing, Shoes & Jewelry, Shoes & Accessori... [repeated 2x across cluster]
# (_remote_exec_single_chain pid=10549) . fn=<function Map.register.<locals>.caller.<locals>.<lambda> at 0x127b34d30>, obj=            salesRankDict
# (_remote_exec_single_chain pid=10549) 0                      {}
# (_remote_exec_single_chain pid=10549) 1                      {}
# (_remote_exec_single_chain pid=10549) 2                      {}
# (_remote_exec_single_chain pid=10549) 3                      {}
# (_remote_exec_single_chain pid=10549) 4                      {}
# (_remote_exec_single_chain pid=10549) 56625  {'Books': 4217637}
# (_remote_exec_single_chain pid=10549) 56626  {'Books': 2602273}
# (_remote_exec_single_chain pid=10549) 56627  {'Books': 2630260}
# (_remote_exec_single_chain pid=10549) 56628   {'Books': 911511}
# (_remote_exec_single_chain pid=10549) 56629   {'Books': 124507}
# (_remote_exec_single_chain pid=10549)
# (_remote_exec_single_chain pid=10549) . args=(            salesRankDict
# (_remote_exec_single_chain pid=10549) 0                      {}
# (_remote_exec_single_chain pid=10549) 1                      {}
# (_remote_exec_single_chain pid=10549) 2                      {}
# (_remote_exec_single_chain pid=10549) 3                      {}
# (_remote_exec_single_chain pid=10549) 4                      {}
# (_remote_exec_single_chain pid=10549) 56625  {'Books': 4217637}
# (_remote_exec_single_chain pid=10549) 56626  {'Books': 2602273}
# (_remote_exec_single_chain pid=10549) 56627  {'Books': 2630260}
# (_remote_exec_single_chain pid=10549) 56628   {'Books': 911511}
# (_remote_exec_single_chain pid=10549) 56629   {'Books': 124507}
# (_remote_exec_single_chain pid=10549)
# (_remote_exec_single_chain pid=10549) [56630 rows x 1 columns], <function Map.register.<locals>.caller.<locals>.<lambda> at 0x127b34d30>, 0, 0, 0, 1), chain=[0, 1]
# (_remote_exec_multi_chain pid=10550) 361823  [[Books, Literature & Fiction], [Books, Romanc...
# (_remote_exec_multi_chain pid=10550) 361824  [[Books, Reference, Writing, Research & Publis...
# (_remote_exec_multi_chain pid=10550) 361825  [[Books, Computers & Technology, Games & Strat...
# (_remote_exec_multi_chain pid=10550) 361826  [[Books, Literature & Fiction], [Books, Myster...
# (_remote_exec_multi_chain pid=10550) 361827  [[Books, Literature & Fiction, United States, ...
# (_remote_exec_multi_chain pid=10550) 416544  [[CDs & Vinyl, Broadway & Vocalists, Tradition...
# (_remote_exec_multi_chain pid=10550) 416545  [[CDs & Vinyl, Blues], [CDs & Vinyl, Pop], [CD...
# (_remote_exec_multi_chain pid=10550) 416546  [[CDs & Vinyl, Jazz], [CDs & Vinyl, Latin Musi...
# (_remote_exec_multi_chain pid=10550) 416547  [[CDs & Vinyl, Blues, Contemporary Blues], [CD...
# (_remote_exec_multi_chain pid=10550) 416548  [[CDs & Vinyl, Alternative Rock, Hardcore & Pu...
# (_remote_exec_multi_chain pid=10550)
# (_remote_exec_multi_chain pid=10550) 361823  [[Books, Literature & Fiction], [Books, Romanc...
# (_remote_exec_multi_chain pid=10550) 361824  [[Books, Reference, Writing, Research & Publis...
# (_remote_exec_multi_chain pid=10550) 361825  [[Books, Computers & Technology, Games & Strat...
# (_remote_exec_multi_chain pid=10550) 361826  [[Books, Literature & Fiction], [Books, Myster...
# (_remote_exec_multi_chain pid=10550) 361827  [[Books, Literature & Fiction, United States, ...
# (_remote_exec_multi_chain pid=10550) 416544  [[CDs & Vinyl, Broadway & Vocalists, Tradition...
# (_remote_exec_multi_chain pid=10550) 416545  [[CDs & Vinyl, Blues], [CDs & Vinyl, Pop], [CD...
# (_remote_exec_multi_chain pid=10550) 416546  [[CDs & Vinyl, Jazz], [CDs & Vinyl, Latin Musi...
# (_remote_exec_multi_chain pid=10550) 416547  [[CDs & Vinyl, Blues, Contemporary Blues], [CD...
# (_remote_exec_multi_chain pid=10550) 416548  [[CDs & Vinyl, Alternative Rock, Hardcore & Pu...
# (_remote_exec_multi_chain pid=10550)
# (_remote_exec_multi_chain pid=10549) . fn=<function Map.register.<locals>.caller.<locals>.<lambda> at 0x14099a9e0>, obj=             salesRankDict
# (_remote_exec_multi_chain pid=10549) 56630   {'Books': 1418458}
# (_remote_exec_multi_chain pid=10549) 56631   {'Books': 3100252}
# (_remote_exec_multi_chain pid=10549) 56632   {'Books': 1763159}
# (_remote_exec_multi_chain pid=10549) 56633   {'Books': 2377168}
# (_remote_exec_multi_chain pid=10549) 56634    {'Books': 610636}
# (_remote_exec_multi_chain pid=10549) 139235   {'Books': 160490}
# (_remote_exec_multi_chain pid=10549) 139236  {'Books': 1734789}
# (_remote_exec_multi_chain pid=10549) 139237  {'Books': 1940212}
# (_remote_exec_multi_chain pid=10549) 139238    {'Books': 72793}
# (_remote_exec_multi_chain pid=10549) 139239   {'Books': 447186}
# (_remote_exec_multi_chain pid=10549)
# (_remote_exec_multi_chain pid=10549) . args=(            salesRankDict
# (_remote_exec_multi_chain pid=10549) 0      {'Books': 1418458}
# (_remote_exec_multi_chain pid=10549) 1      {'Books': 3100252}
# (_remote_exec_multi_chain pid=10549) 2      {'Books': 1763159}
# (_remote_exec_multi_chain pid=10549) 3      {'Books': 2377168}
# (_remote_exec_multi_chain pid=10549) 4       {'Books': 610636}
# (_remote_exec_multi_chain pid=10549) 82605   {'Books': 160490}
# (_remote_exec_multi_chain pid=10549) 82606  {'Books': 1734789}
# (_remote_exec_multi_chain pid=10549) 82607  {'Books': 1940212}
# (_remote_exec_multi_chain pid=10549) 82608    {'Books': 72793}
# (_remote_exec_multi_chain pid=10549) 82609   {'Books': 447186}
# (_remote_exec_multi_chain pid=10549)
# (_remote_exec_multi_chain pid=10549) [82610 rows x 1 columns], <function PandasDataframe._propagate_index_objs.<locals>.apply_idx_objs at 0x127b34d30>, 0, 1, 'idx', RangeIndex(start=56630, stop=139240, step=1), 0, 1, <function Map.register.<locals>.caller.<locals>.<lambda> at 0x14099a9e0>, 0, 0, 0, 1), chain=[0, 1]
# (_remote_exec_multi_chain pid=10550)
# (_remote_exec_multi_chain pid=10550)
# (_remote_exec_multi_chain pid=10557)
# (_remote_exec_multi_chain pid=10557)
# (_remote_exec_multi_chain pid=10549)
# (_remote_exec_multi_chain pid=10549)
# (_remote_exec_multi_chain pid=10550) 416549     {'Music': 352535}
# (_remote_exec_multi_chain pid=10550) 416550     {'Music': 177385}
# (_remote_exec_multi_chain pid=10550) 416551     {'Music': 148399}
# (_remote_exec_multi_chain pid=10550) 416552     {'Music': 312927}
# (_remote_exec_multi_chain pid=10550) 416553     {'Music': 420158}
# (_remote_exec_multi_chain pid=10550) 473436      {'Shoes': 57131}
# (_remote_exec_multi_chain pid=10550) 473437  {'Clothing': 115313}
# (_remote_exec_multi_chain pid=10550) 473438  {'Clothing': 196776}
# (_remote_exec_multi_chain pid=10550) 473440      {'Shoes': 65481}
# (_remote_exec_multi_chain pid=10550)
# (_remote_exec_multi_chain pid=10550) 0         {'Music': 352535}
# (_remote_exec_multi_chain pid=10550) 1         {'Music': 177385}
# (_remote_exec_multi_chain pid=10550) 2         {'Music': 148399}
# (_remote_exec_multi_chain pid=10550) 3         {'Music': 312927}
# (_remote_exec_multi_chain pid=10550) 4         {'Music': 420158}
# (_remote_exec_multi_chain pid=10550) 56887      {'Shoes': 57131}
# (_remote_exec_multi_chain pid=10550) 56888  {'Clothing': 115313}
# (_remote_exec_multi_chain pid=10550) 56889  {'Clothing': 196776}
# (_remote_exec_multi_chain pid=10550) 56891      {'Shoes': 65481}
# (_remote_exec_multi_chain pid=10550)
# (_remote_exec_multi_chain pid=10555)
# (_remote_exec_multi_chain pid=10555)
# (_remote_exec_multi_chain pid=10557) 473443           {'Toys & Games': 13041}
# (_remote_exec_multi_chain pid=10557) 473445  {'Sports &amp; Outdoors': 25755}
# (_remote_exec_multi_chain pid=10557)
# (_remote_exec_multi_chain pid=10557) 2               {'Toys & Games': 13041}
# (_remote_exec_multi_chain pid=10557) 4      {'Sports &amp; Outdoors': 25755}
# (_remote_exec_multi_chain pid=10557)
# (_remote_exec_multi_chain pid=10549) 606784  {'Movies & TV': 227966}
# (_remote_exec_multi_chain pid=10549) 606785  {'Movies & TV': 172423}
# (_remote_exec_multi_chain pid=10549) 606786  {'Movies & TV': 135158}
# (_remote_exec_multi_chain pid=10549) 606787  {'Movies & TV': 100145}
# (_remote_exec_multi_chain pid=10549) 606788   {'Movies & TV': 65223}
# (_remote_exec_multi_chain pid=10549)
# (_remote_exec_multi_chain pid=10549) 64854  {'Movies & TV': 227966}
# (_remote_exec_multi_chain pid=10549) 64855  {'Movies & TV': 172423}
# (_remote_exec_multi_chain pid=10549) 64856  {'Movies & TV': 135158}
# (_remote_exec_multi_chain pid=10549) 64857  {'Movies & TV': 100145}
# (_remote_exec_multi_chain pid=10549) 64858   {'Movies & TV': 65223}
# (_remote_exec_multi_chain pid=10549)
# (_remote_exec_multi_chain pid=10555) 657001    {'Video Games': 1550}
# (_remote_exec_multi_chain pid=10555) 657002      {'Video Games': 30}
# (_remote_exec_multi_chain pid=10555) 657003   {'Video Games': 32194}
# (_remote_exec_multi_chain pid=10555) 657004      {'Video Games': 46}
# (_remote_exec_multi_chain pid=10555) 657005    {'Video Games': 7179}
# (_remote_exec_multi_chain pid=10555)
# (_remote_exec_multi_chain pid=10555) 50212    {'Video Games': 1550}
# (_remote_exec_multi_chain pid=10555) 50213      {'Video Games': 30}
# (_remote_exec_multi_chain pid=10555) 50214   {'Video Games': 32194}
# (_remote_exec_multi_chain pid=10555) 50215      {'Video Games': 46}
# (_remote_exec_multi_chain pid=10555) 50216    {'Video Games': 7179}
# (_remote_exec_multi_chain pid=10555)
# (_remote_exec_single_chain pid=10555)
# (_remote_exec_single_chain pid=10555)
# (_remote_exec_single_chain pid=10557)
# (_remote_exec_single_chain pid=10557)
# (_remote_exec_single_chain pid=10549)
# (_remote_exec_single_chain pid=10549)
# (_remote_exec_single_chain pid=10550)
# (_remote_exec_single_chain pid=10550)
# (_remote_exec_single_chain pid=10555)
# (_remote_exec_single_chain pid=10555)
# (_remote_exec_single_chain pid=10557)
# (_remote_exec_single_chain pid=10557)
# (_remote_exec_single_chain pid=10557)
# (_remote_exec_single_chain pid=10557)
# (_remote_exec_single_chain pid=10549)
# (_remote_exec_single_chain pid=10549)
# (_remote_exec_single_chain pid=10550)
# (_remote_exec_single_chain pid=10550)
# (_remote_exec_single_chain pid=10550)
# (_remote_exec_single_chain pid=10550)

# %%
ROOT = ""
ROOT = os.path.expanduser(ROOT) # expand user contractions

# %%
product_data = pd.read_csv(os.path.join(ROOT, "metadata_header.csv"))

# make sure columns are of the right dtypes
for column in ["salesRankDict", "categories", "related"]:
    product_data[column] = product_data[column].apply(lambda x: literal_eval(x) if not pd.isna(x) else None)

# %% [markdown]
# # Task 1.1: flatten `categories` and `salesRank`
#
# * From `categories` (a list of lists), take the first element of the first list (i.e., `categories[0][0]`) and place it in a new column `category`. If missing/empty, set `null`.
# * `salesRankDict` contains at most one pair of (key, value). From `salesRankDict`, extract the key and the value into new columns `salesCategory` and `salesRank`. If missing/empty, set `null`.

# %%
def part1(product_data):
    
    # Column names
    salesRankDict_column = 'salesRankDict'
    categories_column = 'categories' 
    asin_column = 'asin'
    
    # Outputs
    category_column = 'category' 
    salesCategory_column = 'salesCategory' 
    salesRank_column = 'salesRank' 

    res = {
        'count_total': None,
        'mean_salesRank': None,
        'variance_salesRank': None, 
        'numNulls_category': None,
        'countDistinct_category': None,
        'numNulls_salesCategory': None,
        'countDistinct_salesCategory': None
    }
    
    # Functions for preprocessing
    def preprocess_cat(cats):
        # YOUR CODE HERE
        raise NotImplementedError()

    def get_sales_cat(salesRank):
        # YOUR CODE HERE
        raise NotImplementedError()

    def get_sales_rank(salesRank):
        # YOUR CODE HERE
        raise NotImplementedError()

    # Apply preprocessing functions
    product_data[category_column] = product_data[categories_column].apply(preprocess_cat)
    product_data[salesCategory_column] = product_data[salesRankDict_column].apply(get_sales_cat)
    product_data[salesRank_column] = product_data[salesRankDict_column].apply(get_sales_rank)

    # Calculate statistics    
    # YOUR CODE HERE
    raise NotImplementedError()

    # Put results in a dictionary
    res = {
        'count_total': int(count_total),
        'mean_salesRank': float(mean_salesRank),
        'variance_salesRank': float(variance_salesRank),
        'numNulls_category': int(numNulls_category),
        'countDistinct_category': int(countDistinct_category),
        'numNulls_salesCategory': int(numNulls_salesCategory),
        'countDistinct_salesCategory': int(countDistinct_salesCategory)
    }

    return res

# %%
res = part1(product_data)

# %%
import json
expected_path = Path("expected_1_1.json").expanduser()
with open(expected_path) as expected_file:
    expected = json.load(expected_file)

assert compare_dicts(expected, res), "Task 1.1 result mismatch"
print("✅ Task 1.1 output matches expected.")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[8], line 6
#       3 with open(expected_path) as expected_file:
#       4     expected = json.load(expected_file)
# ----> 6 assert compare_dicts(expected, res), "Task 1.1 result mismatch"
#       7 print("✅ Task 1.1 output matches expected.")
#
# AssertionError: Task 1.1 result mismatch

# %% [markdown]
# # Task 1.2: flatten `related`
#
# * For each row, compute mean price of products referenced by `related["also_viewed"]`. Ignore the ASINs not present in `product` or with `price=null`. Do not impute None (e.g., do not use fillna(0) or similar).

# %%
def part2(product_data):
    #Column names
    asin_column = 'asin'
    price_column = 'price'
    related_column = 'related'
    
    attribute = 'also_viewed'
    
    #Outputs
    meanPriceAlsoViewed_column = 'meanPriceAlsoViewed'
    
    res = {
        'count_total': None,
        'mean_meanPriceAlsoViewed': None,
        'variance_meanPriceAlsoViewed':  None,
        'numNulls_meanPriceAlsoViewed':  None
    }
    
    # Get also_viewed (a list of asins) from related_column and make it a new column
    def get_also_viewed(related):
        # YOUR CODE HERE
        raise NotImplementedError()
    
    product_data[attribute] = product_data[related_column].apply(get_also_viewed)

    # Make joins to compute meanPriceAlsoViewed
    # Then calculate Statistics
    # YOUR CODE HERE
    raise NotImplementedError()
    
    # Put results in res
    res = {
        'count_total': int(count_total),
        'mean_meanPriceAlsoViewed': float(mean_meanPriceAlsoViewed),
        'variance_meanPriceAlsoViewed': float(variance_meanPriceAlsoViewed),
        'numNulls_meanPriceAlsoViewed': int(numNulls_meanPriceAlsoViewed)
    }
    return res

# %%
res = part2(product_data)

# %%
import json
expected_path = Path("expected_1_2.json").expanduser()
with open(expected_path) as expected_file:
    expected = json.load(expected_file)

assert compare_dicts(expected, res), "Task 1.2 result mismatch"
print("✅ Task 1.2 output matches expected.")

# %% [markdown]
# # Task 1.3: Impute `price`
#
# - Impute `price` with the *mean* and write to `meanImputedPrice`.
# - Impute `price` with the *median* and write to `medianImputedPrice`.
# - For `title`, replace `null` with the string `"unknown"` and write to `unknownImputedTitle`.

# %%
from sklearn.impute import SimpleImputer

def part3(product_data):

    price_column = 'price'
    title_column = 'title'
    
    # Outputs
    meanImputedPrice_column = 'meanImputedPrice'
    medianImputedPrice_column = 'medianImputedPrice'
    unknownImputedTitle_column = 'unknownImputedTitle'
    
    res = {
        'count_total': None,
        'mean_meanImputedPrice': None,
        'variance_meanImputedPrice': None,
        'numNulls_meanImputedPrice': None,
        'mean_medianImputedPrice': None,
        'variance_medianImputedPrice': None,
        'numNulls_medianImputedPrice': None,
        'numUnknowns_unknownImputedTitle': None,
    }
    
    # Define Imputers
    mean_imputer = SimpleImputer(strategy='mean')
    median_imputer = SimpleImputer(strategy='median')

    # Apply impute data from price column using both mean and median, fill titles with unknowns.
    # Then calculate statistics.
    # YOUR CODE HERE
    raise NotImplementedError()
    
    # Put results in res 
    res = {
        'count_total': int(count_total),
        'mean_meanImputedPrice': float(mean_meanImputedPrice),
        'variance_meanImputedPrice': float(variance_meanImputedPrice),
        'numNulls_meanImputedPrice': int(numNulls_meanImputedPrice),
        'mean_medianImputedPrice': float(mean_medianImputedPrice),
        'variance_medianImputedPrice': float(variance_medianImputedPrice),
        'numNulls_medianImputedPrice': int(numNulls_medianImputedPrice),
        'numUnknowns_unknownImputedTitle': int(numUnknowns_unknownImputedTitle),
    }
    return res

# %%
res = part3(product_data)

# %%
import json
expected_path = Path("expected_1_3.json").expanduser()
with open(expected_path) as expected_file:
    expected = json.load(expected_file)

assert compare_dicts(expected, res), "Task 1.3 result mismatch"
print("✅ Task 1.3 output matches expected.")

# %% [markdown]
# # Is that it?
#
# To make this dataset ready for ML tasks, there are many more feature engineering steps to be done, which we haven't covered here. For example, textual data can be fed into a Word2Vec model for meaningful embeddings. We've stuck with a few simple operations here. Next, in task 2, you'll use preprocessed train and test datasets to train Xgboost models in a multi-node fashion!

# %%
# shutdown!
ray.shutdown()
